# %% [markdown]
# # Latitude and Longitude details of Kannur District

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_875c8f21c0ab48679dce67bb76a49cc9 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='iqI-YWn1zcDve-qXaLQGgYWleInhkSnecnfyRLCRfQhV',
    ibm_auth_endpoint="https://iam.eu-gb.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_875c8f21c0ab48679dce67bb76a49cc9.get_object(Bucket='battleneighbourhood-donotdelete-pr-ssbhzuigxpfx8r',Key='loc_details.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
df_data_0=pd.read_csv(body)
# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.df_data_0 = pd.read_csv(body)
df_data_0.head()
# Out:
#              Location  Pincode   State District
# 0           Alacherry   670650  Kerala   Kannur
# 1             Alakode   670571  Kerala   Kannur
# 2  Alakode-kuttaramba   670571  Kerala   Kannur
# 3              Alavil   670008  Kerala   Kannur
# 4         Ambayathode   670651  Kerala   Kannur

# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: ratelim in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2019.9.11)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)

# %%
#now, using Geocoder and Google API, we get the Latitude and Longitude of each area
import geocoder
GOOGLE_API_KEY='AIzaSyAQWqMTOcyLBRDR2skO4F_5QEWzNDOlUHw'

#function to get latitude and longitude
def get_latlng(postal_code):
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Kannur'.format(postal_code), key=GOOGLE_API_KEY)
        lat_lng_coords = g.latlng
    return lat_lng_coords

#put new column of latitude and logitude into dataframe
postal_codes1 = df_data_0['Location']    
coords = [ get_latlng(postal_code) for postal_code in postal_codes1.tolist() ]

df_data_0_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df_data_0['Latitude'] = df_data_0_coords['Latitude']
df_data_0['Longitude'] = df_data_0_coords['Longitude']
df_data_0.head(387)
# Out:
#                    Location  Pincode   State District   Latitude  Longitude
# 0                 Alacherry   670650  Kerala   Kannur  11.874477  75.370366
# 1                   Alakode   670571  Kerala   Kannur  12.190978  75.467331
# 2        Alakode-kuttaramba   670571  Kerala   Kannur  12.190978  75.467331
# 3                    Alavil   670008  Kerala   Kannur  11.877784  75.357539
# 4               Ambayathode   670651  Kerala   Kannur  11.863742  75.889703
# 5                   Ambilat   670701  Kerala   Kannur  11.852129  75.550590
# 6             Anchampeedika   670331  Kerala   Kannur  11.978009  75.350709
# 7              Angadikadavu   670706  Kerala   Kannur  12.033466  75.744899
# 8                  Aniyaram   670672  Kerala   Kannur  11.734305  75.584433
# 9               Anjarakandy   670612  Kerala   Kannur  11.885834  75.485089
# 10                    Annur   670332  Kerala   Kannur  11.232103  77.106716
# 11                    Arabi   670705  Kerala   Kannur  31.835005 -83.743039
# 12                   Aralam   670704  Kerala   Kannur  11.967640  75.772033
# 13              Aralam Farm   670673  Kerala   Kannur  11.937284  75.768232
# 14                    Arang   670582  Kerala   Kannur  11.874477  75.370366
# 15               Aravanchal   670307  Kerala   Kannur  12.211663  75.279988
# 16               Areekamala   670582  Kerala   Kannur  12.132892  75.577157
# 17                     Aril   670143  Kerala   Kannur  11.874477  75.370366
# 18          Arivilanjapoyil   670571  Kerala   Kannur  12.254468  75.478306
# 19                    Aroli   670566  Kerala   Kannur  11.984557  75.380936
# 20              Atakkathode   670674  Kerala   Kannur  11.921417  75.847585
# 21                Attadappa   670006  Kerala   Kannur  11.865457  75.415984
# 22         Ayithara Mambram   670643  Kerala   Kannur  11.869728  75.603798
# 23                 Azhikkal   670009  Kerala   Kannur  11.917065  75.335387
# 24                 Azhikode   670009  Kerala   Kannur  11.917065  75.335387
# 25           Azhikode South   670009  Kerala   Kannur  11.908579  75.332472
# 26                   Bavode   670622  Kerala   Kannur  11.862183  75.483135
# 27              Burnacherry   670013  Kerala   Kannur  11.859131  75.368909
# 28               Chala East   670621  Kerala   Kannur  11.867616  75.438114
# 29                   Chalad   670014  Kerala   Kannur  11.883045  75.348506
# ..                      ...      ...     ...      ...        ...        ...
# 355                Thottada   670007  Kerala   Kannur  11.842445  75.421362
# 356           Thrichambaram   670141  Kerala   Kannur  12.031240  75.365994
# 357              Thuvakunnu   670693  Kerala   Kannur  11.759187  75.636811
# 358              Tiruvangad   670103  Kerala   Kannur  11.746093  75.500968
# 359               Udayagiri   670571  Kerala   Kannur  12.240706  75.482535
# 360                 Ulikkal   670705  Kerala   Kannur  12.037527  75.670265
# 361                  Uliyil   670702  Kerala   Kannur  11.955667  75.647472
# 362              Ummenchira   670649  Kerala   Kannur  11.791720  75.511697
# 363               Uruvachal   670702  Kerala   Kannur  11.897131  75.584797
# 364             Vadakkumbad   670109  Kerala   Kannur  12.155015  75.185181
# 365  Vadakkumbad-ramanthali   670330  Kerala   Kannur  12.080081  75.188099
# 366            Valapattanam   670010  Kerala   Kannur  11.926168  75.349963
# 367                   Varam   670594  Kerala   Kannur  11.907018  75.408251
# 368            Vattiamthode   670705  Kerala   Kannur  11.874477  75.370366
# 369               Vayalalam   670102  Kerala   Kannur  11.736268  75.514568
# 370                Vayannur   670650  Kerala   Kannur  11.871705  75.685239
# 371          Vayattuparamba   670582  Kerala   Kannur  12.152549  75.463893
# 372                 Veerpad   670704  Kerala   Kannur  11.974941  75.751685
# 373               Velimanam   670704  Kerala   Kannur  11.981107  75.763313
# 374                  Vellad   670571  Kerala   Kannur  12.161993  75.495640
# 375             Vellarvelly   670673  Kerala   Kannur  11.898182  75.707994
# 376                 Vellora   670306  Kerala   Kannur  12.174152  75.358707
# 377                Vellunni   670674  Kerala   Kannur  11.874477  75.370366
# 378                  Vellur   670346  Kerala   Kannur  12.154885  75.207043
# 379                  Vengad   670612  Kerala   Kannur  11.880378  75.536404
# 380          Vengara-kannur   670305  Kerala   Kannur  12.038748  75.246448
# 381              Vijayagiri   670571  Kerala   Kannur  12.198368  75.514022
# 382               Vilakkode   670703  Kerala   Kannur  11.954331  75.701031
# 383             Vilakkottur   670693  Kerala   Kannur  11.757153  75.651357
# 384             Vilayancode   670501  Kerala   Kannur  12.004827  75.750958
#
# [385 rows x 6 columns]

# %%
from IPython.display import HTML
import base64  
import pandas as pd  

def create_download_link(df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv(index =False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(df_data_0)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
